# %%
import pandas as pd

# %%
df = pd.read_parquet(path="./articles.parquet", engine='pyarrow')
df['article_type'].unique()
df
# Out:
#        article_id                                             title  \
# 0         3037230        Ishockey-spiller: Jeg troede jeg skulle dø
# 1         3044020                  Prins Harry tvunget til dna-test
# 2         3057622                       Rådden kørsel på blå plader
# 3         3073151                         Mærsk-arvinger i livsfare
# 4         3193383                    Skød svigersøn gennem babydyne
# ...           ...                                               ...
# 11772     9803492    Vilde billeder: Vulkan i udbrud i ferieparadis
# 11773     9803505               Flyvende Antonsen knuser topspiller
# 11774     9803525  Dansk skuespiller: - Jeg nægtede, at jeg var syg
# 11775     9803560       Så slemt er det: 14.000 huse er oversvømmet
# 11776     9803607       Aktion mod svindlere: Seks personer anholdt
#
#                                                 subtitle  last_modified_time  \
# ...

# %%
behaviors_df = pd.read_parquet('./train/behaviors.parquet')
behaviors_df['inview_cnt'] = behaviors_df['article_ids_inview'].str.len()
behaviors_df['inview_cnt'].unique()
behaviors_df.loc[behaviors_df['article_ids_clicked'].str.len() > 1]
behaviors_df
# Out:
#        impression_id  article_id     impression_time  read_time  \
# 0              48401         NaN 2023-05-21 21:06:50       21.0
# 1             152513   9778745.0 2023-05-24 07:31:26       30.0
# 2             155390         NaN 2023-05-24 07:30:33       45.0
# 3             214679         NaN 2023-05-23 05:25:40       33.0
# 4             214681         NaN 2023-05-23 05:31:54       21.0
# ...              ...         ...                 ...        ...
# 24719      579983230         NaN 2023-05-22 08:30:52       35.0
# 24720      579983231         NaN 2023-05-22 08:31:34       89.0
# 24721      579984721   9774541.0 2023-05-22 08:51:33      123.0
# 24722      579984723   9775699.0 2023-05-22 08:53:36       73.0
# 24723      580097289   9770541.0 2023-05-18 10:56:49      107.0
#
#        scroll_percentage  device_type  \
# 0                    NaN            2
# 1                  100.0            1
# 2                    NaN            1
# 3                    NaN            2
# ...

# %%
history_parquet = pd.read_parquet('./train/history.parquet')
history_parquet
# Out:
#       user_id                              impression_time_fixed  \
# 0       13538  [2023-04-27T10:17:43.000000, 2023-04-27T10:18:...
# 1       58608  [2023-04-27T18:48:09.000000, 2023-04-27T18:48:...
# 2       95507  [2023-04-27T15:20:28.000000, 2023-04-27T15:20:...
# 3      106588  [2023-04-27T08:29:09.000000, 2023-04-27T08:29:...
# 4      617963  [2023-04-27T14:42:25.000000, 2023-04-27T14:43:...
# ...       ...                                                ...
# 1585  1122370  [2023-05-09T06:50:19.000000, 2023-05-09T06:51:...
# 1586  1718049  [2023-05-17T05:04:36.000000, 2023-05-17T05:04:...
# 1587  1178033  [2023-04-29T19:36:47.000000, 2023-04-29T19:37:...
# 1588   395912  [2023-05-12T05:12:34.000000, 2023-05-12T05:12:...
# 1589  2539047  [2023-05-09T10:37:17.000000, 2023-05-09T10:37:...
#
#                                 scroll_percentage_fixed  \
# 0     [100.0, 35.0, 100.0, 24.0, 100.0, 23.0, 100.0,...
# 1     [37.0, 61.0, 100.0, 100.0, 55.0, 100.0, 100.0,...
# ...

# %%
history_parquet = pd.read_parquet('./validation/history.parquet')
history_parquet
# Out:
#       user_id                              impression_time_fixed  \
# 0      750497  [2023-05-04T09:42:39.000000, 2023-05-04T09:43:...
# 1       22779  [2023-05-04T07:53:42.000000, 2023-05-04T15:59:...
# 2      373598  [2023-05-04T07:51:58.000000, 2023-05-04T09:59:...
# 3      383378  [2023-05-04T07:27:57.000000, 2023-05-04T07:29:...
# 4      411733  [2023-05-04T17:09:09.000000, 2023-05-04T17:09:...
# ...       ...                                                ...
# 1557   626090  [2023-05-16T15:24:43.000000, 2023-05-16T15:24:...
# 1558  1143249  [2023-05-24T13:08:55.000000, 2023-05-24T13:09:...
# 1559   109970  [2023-05-19T12:14:25.000000, 2023-05-19T12:15:...
# 1560   330156  [2023-05-25T04:30:51.000000, 2023-05-25T04:34:...
# 1561  2385386  [2023-05-12T09:14:08.000000, 2023-05-12T09:14:...
#
#                                 scroll_percentage_fixed  \
# 0     [100.0, 65.0, 100.0, 100.0, 100.0, 100.0, 100....
# 1     [52.0, 39.0, 62.0, 38.0, 74.0, 19.0, 30.0, 56....
# ...

# %%
behaviors_df = pd.read_parquet('./validation/behaviors.parquet')
behaviors_df['inview_cnt'] = behaviors_df['article_ids_inview'].str.len()
behaviors_df['inview_cnt'].unique()
behaviors_df
# Out:
#        impression_id  article_id     impression_time  read_time  \
# 0             144772         NaN 2023-05-30 14:21:34       29.0
# 1             144777         NaN 2023-05-30 14:22:11       10.0
# 2             196487         NaN 2023-05-27 19:54:18       16.0
# 3             196495         NaN 2023-05-27 19:53:48       25.0
# 4             196496         NaN 2023-05-27 19:56:28       11.0
# ...              ...         ...                 ...        ...
# 25351      578776841         NaN 2023-05-26 20:46:25       63.0
# 25352      578776846   9783317.0 2023-05-26 20:47:28       23.0
# 25353      578777590   9780467.0 2023-05-26 20:43:52       21.0
# 25354      578783544         NaN 2023-05-26 18:59:17       10.0
# 25355      579246466         NaN 2023-05-26 08:08:12        5.0
#
#        scroll_percentage  device_type  \
# 0                    NaN            2
# 1                    NaN            2
# 2                    NaN            2
# 3                    NaN            2
# ...
